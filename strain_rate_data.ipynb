# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Read CSV file
csv = pd.read_csv("csv/result-chugoku-0121.csv")
chugoku_df = pd.DataFrame(csv)

# %%
chugoku_df = chugoku_df[chugoku_df["strain-rate"]!=0]
chugoku_df["strain-rate"].describe()
# Out:
# count    1.080000e+02
# mean     4.543222e-09
# std      4.394455e-09
# min      1.940586e-11
# 25%      1.127184e-09
# 50%      3.232081e-09
# 75%      7.001338e-09
# max      2.036264e-08
# Name: strain-rate, dtype: float64

# %%
chugoku_df["strain-rate"].plot()
plt.show()

# %%
# Read CSV file
csv = pd.read_csv("csv/result-kyusyu-0121.csv")
kyusyu_df = pd.DataFrame(csv)

# %%
kyusyu_df = kyusyu_df[kyusyu_df["strain-rate"] != 0]
kyusyu_df["strain-rate"].describe()
# Out:
# count    9.900000e+01
# mean     4.481503e-09
# std      5.512739e-09
# min      2.536692e-11
# 25%      8.769897e-10
# 50%      2.777652e-09
# 75%      5.120994e-09
# max      2.935284e-08
# Name: strain-rate, dtype: float64

# %%
kyusyu_df["strain-rate"].plot()
plt.show()
